# %% [markdown]
# ### Anteckningar för kursen Statistiska meteoder

# %% [markdown]
# ### Imorgon tisdag
# - gå genom alla lektoner igen och göra anteckningar.
# - Skriva in alla anteckningar här och skriva rent.

# %% [markdown]
# Stockastiska varibler, även kallade Stokastiska
# Random Variables, slump variabler
#
# Diskreta s.v, kontunerliga s.v. =  distribution
#
# s.v = Stokatisk variabel
#
# Statistike vs Sannolikhet

# %% [markdown]
# ***Stocakstiska variabler***
#
# **Exemple 1:**
# Låt X vara antalet brunögda barn ett visst par föräldrar föder. Säg att de har två barn; då kan X anta värden 0, 1 ,2.
# Vi skriver  X = 1 om ett barn av barnen har bruna ögon.
# X är en diskret s.v.
#
#
# **Exemple 2:**
# Låt T vara klockslaget då strömanvändningen i staasnättet når sin topp.
# T är en konturnerlig stokastiks variable
#
# Om en variabel är konturnerlig för att man kan inte sätta en bestämd ettiket på värdet.
#
#
# **Distributioner**
# X är en s.v. Om Vi upprepat drar värden från X och plottar en graf. Kommer vi slå varje värde lika många gånger och grafen blir helt rak. Som om vi slår en tärning
# Distributionen kommer så vara uniform.
#
# Om vi slår en miljon tärningar så blir det en normalfördelning. Grafen blir som en jämn kulle. Enlight den centralgränsvärdes saten så blir det alltide en normalfördelad distrubution med tillräkligt stor mängd data punkter.
#
# Vad är en Distribution?
# Det är summan av sannolikhets distribution.
#
# Låt X vara en diskret s.v.
# F(x) = P[X <= x]
# Då kallas F för kumulativ distributions funktionen (CDF)
#
# Täthetsfunktion:
# f(x) = P[X = x]
# Här tittar vi på en punkt i kurvan
# 1. f(x) => för alla x
# 2. Suman av f(x) = x
#
# Sum F(x0) = sum x <= x0 f(x)
#
# **Väntevärde (Expectation)**
# Average, mean, expected value
# Genomsnitt, medel, väntvärde
#
# Viktigt bit i statstik, mitten värdet. Behövs för att hitta mitten av datan, så man vet vart man ska utgå ifrån.
# E[H(x)] = $\sum {x}$ H(x)f(x)
# E[X] = sum x f(x)
#
# Räkneregeler för väntvärden:
# E[c] = c
# E[cx] = c E[x]
# E[x inte = y] = E[x] + E[y] (Detta är ett linjärt förhållande, om dom är oberoende från varandra)
#
# **Varians (Variance)**
#
# Var X = $\sigma$ = E[$(x-\mu)^2$] = E[$x^2] - (E[x]^2$)
#
# Avvikelse
# $\mu$ = $\sqrt{var x}$ = $\sqrt{\mu^2}$
#
# Räkneregeler
# Var c = 0
# Var cX = $c^2$ Var X
# Om $x*v_{1}$ oberoende, Var (X+Y) = Var X + Var Y
#
#
# **Gemensamma Distributoner (Joint Distributions)**
# Här finns det ett bettingat beroende mellan dom olika variablerna.
#
# 1. $f_{xy}$ (X,Y) $\ge$ 0
# 2. $\sum{x}$ $\sum{y}$ $f_{xy}$ (x, y) = 1
#
# Marginel täthet, vi kan inte anvnda vanlig täthet funktioner. För att beräkna täthet måste vi fixer en av varibelrna.
# $f_{x}$ (x) = $\sum{y}$ $f_{xy}(x,y)$
#
# $f_{y}$ (y) = $\sum{y} $f_{xy}(x,y)$
#
# Bettingad täthets funnktion
# $f_{x|y} (x) = $f_{xy}$ / $f_{y}$ (Y)
# $f_{x|y} (x) = $f_{xy}$ / $f_{x}$ (X)
#
# Givet ett X = x så räknar vi här medelt av Y för det x.et.
# Om vi plottar varje $x\in X$ mot Y får vi en regression av X på Y.
# $\mu_{x|y}$ = $\beta_{0}$ + $\beta_{1}$ x är samma som kx+m
# När vi når hit så har vi kunskap ver något i en Distribution. Vi kan här ifrån kunna göra förutsägelser.
#
# En linjär regretion är en medelfördelning. Men kan bli riktigt fel i en Distibrution när punkterna är nära varandra. Leder till att vi måste veta i vilket intervall våran linjära regretion är gilltig.
#
# Låt $Y_{i}$ vara utfallen av en s.v. Y.
# Vikallar den responsvariabel. Forme en tabell.
# $\beta$ kallas prediktorer
#
# $Y_{i}$ = $\beta_{0}$ + $\beta_{1}$ $x_{i}$ + $E_{i}$   E[$E_{i}$] = 0
#
# varje rad:
# $y_{i}$ = $\beta_{0}$ + $\beta_{1}$ + $\epsilon_{i}$
# Hemliga avviskelser från den sanna linjen
#
# efter uppskattning:
# $y_{i}$ = $\beta_{0}$ + $\beta_{1}$ $x_{i}$ + $\epsilon_{i}$
# Kända avvikelser från regressinslinjen, en residual

# %% [markdown]
# ### Eximanering av kurs
#
# Labben:
# Implemtera linjär regression med statiska mått
#
# Tenta:
# Teoretisk
