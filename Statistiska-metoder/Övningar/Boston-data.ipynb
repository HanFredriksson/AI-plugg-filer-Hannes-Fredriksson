# %% [markdown]
# # Boston data övningar
# *Från boken Introduction to Statistical Learning in Python*

# %%
# a)

import pandas as pd
import matplotlib.pyplot as plt

data_path = "../Data/Boston.csv"

data = pd.read_csv(data_path)
data = data.drop("Unnamed: 0", axis=1)
data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio   black  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# *b)*
#
# Data set has 506 rows × 14 columns.
#
# **Columns means**
#
# 1. CRIM: Per capita crime rate by town. It indicates the level of crime in the area.
#
# 2. ZN: Proportion of residential land zoned for lots over 25,000 sq.ft. This feature reflects the area's residential density.
#
# 3. INDUS: Proportion of non-retail business acres per town. This is an indicator of the commercial use of land away from residential areas.
#
# 4. CHAS: Charles River dummy variable (1 if tract bounds river; 0 otherwise). This indicates whether the property is near the Charles River, which may add to the aesthetic value of the neighborhood.
#
# 5. NOX: Nitric oxides concentration (parts per 10 million). It represents the level of industrial pollutants in the area.
#
# 6. RM: Average number of rooms per dwelling. More rooms typically indicate more spacious accommodation.
#
# 7. AGE: Proportion of owner-occupied units built prior to 1940. Older structures might lack newer amenities or could be considered more prestigious depending on the architecture and condition.
#
# 8. DIS: Weighted distances to five Boston employment centres. This feature measures the accessibility to workplaces, which can influence housing prices.
#
# 9. RAD: Index of accessibility to radial highways. Higher values indicate easier access to major roadways.
#
# 10. TAX: Full-value property-tax rate per $10,000. This reflects the annual property tax rate.
#
# 11. PTRATIO: Pupil-teacher ratio by town. Lower values typically indicate better educational facilities, which is a significant factor for families when choosing a home.
#
# 12. BLACK: $(Bk-0.63)^2$ where bk is the propotion of blacks by town.
#
# 13. LSTAT: Procent of lower status of the population.
#
# 14. MEDV: Median value of owner-occuoied homes in $1000's.

# %%
# c)

fig, axes = plt.subplots(ncols=2,
                         nrows=2, 
                         figsize=[15, 10])

axes = axes.ravel()

plot_xy_title = [("rm", "lstat", "RM vs LSTAT"), 
                 ("medv", "lstat", "MEDV vs LSTAT"),
                 ("nox", "dis", "NOX vs DIS"),
                 ("age", "dis", "AGE vs DIS")]

for ax, (x_col, y_col, title) in zip(axes, plot_xy_title):
    ax.scatter(data[x_col], data[y_col])
    ax.set_xlabel(x_col.upper())
    ax.set_ylabel(y_col.upper())
    ax.set_title(title)

plt.tight_layout()

plt.show()

# %% [markdown]
# *RM vs LSTAT*
#
# Find a small correlation between the monitary status and sieze of building/amount of rooms that people wher living in. The more money people, more roome people had. Wich could indecate that peolple with less money had to share samaller dwelings. There where some strong outliers. Which could indicate high end aparment buildings in the center.
#
# *MEDV vs LSTAT*
#
# Here the data is much more clear. The mor people have in there homes, the higher status they have. But looks ther is a cap in the data at 50 000. Which I did some googling to find out why. Ther censor for prices higher, thay put a cap there. Showing the politcal pull of people with real wealth.
#
# *NOX vs DIS*
#
# Trying to find if living closer to commuter and transporttaion routes incresse polution in you area. Wich the datat show a strong correlation for. That as the DIS decreases, the polution gose up. Soo people living closer to highways or industries get wores air quality.
#
# *AGE vs DIS*
#
# Where looking if there is an any evidince of urban sprawl in the data. Is the distans to work is incresing. Which could be an indcarion of newer buildings are being built futher away from central parts and commuter distances are incresing. Showing a sprawl and decreases in urban density. There is a trend of newer buildings being futher from the center. Showing a sprawl is happening.

# %%
# d)

fig, ax = plt.subplots(nrows=3, figsize=(10, 20))

ax[0].scatter(data["medv"], data["crim"])
ax[0].set_xlabel("MEDV (1,000$)")
ax[0].set_ylabel("CRIM (per capita)")
ax[0].set_title("Medv vs Crime")

ax[1].scatter(data["lstat"], data["crim"])
ax[1].set_xlabel("LSTAT %")
ax[1].set_ylabel("CRIM (per capita)")
ax[1].set_title("Lstat, lower status of population vs Crime")

ax[2].scatter(data["dis"], data["crim"])
ax[2].set_xlabel("Dis")
ax[2].set_ylabel("CRIM (per capita)")
ax[2].set_title("Distans to five work centers vs Crime")
# Out:
# Text(0.5, 1.0, 'Distans to five work centers vs Crime')

# %% [markdown]
# *MEDV vs CRIM*
#
# Looking at value of homes vs how much crime it is in those areas shows a strong ralation being poorer that there are more crime. As the medv gose down, the higher risk of crime shows up. But also at the other end there is a small spike in medv higher then 50,000. the data here are censored, so we can not see if really high income areas have higher crime. In areas with hgher value homes show a population with more money to spend, couse ther homes are mor expensiv.
#
# *LSTAT vs CRIM*
#
# To confirm what the data for medv vs crim show. I also looked at the status of the population in areas. Again we see a lower status population incresse the crime rate. Confirming that people in low income and lower calss areas have a higher crime rate. That wealth do relat to crime rate. Woukd be intresting to pull data on policing in these naigbourhoods and se if there is an diffrens in the polce activety in areas with more wealth or less.
#
# *DIS vs CRIM*
#
# Looking here at if the crime are centered around central areas of the city. Which there is a strong relation to being central that the crime rate is higher. But this can be due to central areas are more populated and denser. What would be intresting is also to look at status and distans to centers. If there is more lower status population when gettig closer to the center. If that can paint a more defind picture of the problem. Couse we already know that wealth relat to crime rates.

# %%
plt.scatter(data["dis"], data["lstat"])

# %%
# e)

sorted_data = data.sort_values(by=["crim"],ascending= False)

sorted_data




# plt.bar(sorted_data.index, sorted_data["crim"])
# Out:
#          crim    zn  indus  chas    nox     rm    age     dis  rad  tax  \
# 380  88.97620   0.0  18.10     0  0.671  6.968   91.9  1.4165   24  666
# 418  73.53410   0.0  18.10     0  0.679  5.957  100.0  1.8026   24  666
# 405  67.92080   0.0  18.10     0  0.693  5.683  100.0  1.4254   24  666
# 410  51.13580   0.0  18.10     0  0.597  5.757  100.0  1.4130   24  666
# 414  45.74610   0.0  18.10     0  0.693  4.519  100.0  1.6582   24  666
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 55    0.01311  90.0   1.22     0  0.403  7.249   21.9  8.6966    5  226
# 341   0.01301  35.0   1.52     0  0.442  7.241   49.3  7.0379    1  284
# 285   0.01096  55.0   2.25     0  0.389  6.453   31.9  7.3073    1  300
# 284   0.00906  90.0   2.97     0  0.400  7.088   20.8  7.3073    1  285
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296
#
#      ptratio   black  lstat  medv
# 380     20.2  396.90  17.21  10.4
# ...

# %%
import numpy as np

Y = lstat = data["lstat"]
X = np.column_stack([np.ones(Y.shape[0]), data["rm"]])
b = np.linalg.pinv(X.T @ X) @ X.T @ Y

plt.scatter(X[:, 1], Y)
x = np.linspace(3, 9)
y_hat = b[0] + b[1]*x
plt.plot(x, y_hat, c= "red")
