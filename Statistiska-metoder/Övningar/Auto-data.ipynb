# %% [markdown]
# # Auto Data - Övnings uppgift
# *Från boken Introduction to Statistical Learning in Python*

# %%
import pandas as pd
import numpy as np

data_path = "../Data/Auto.csv"

data = pd.read_csv(data_path)

data.replace("?", np.nan, inplace=True)
data = data.dropna(axis=0, how="any")
data["horsepower"] = data["horsepower"].astype(int)
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0          86    2790          15.6    82
# 393  44.0          4          97.0          52    2130          24.6    82
# 394  32.0          4         135.0          84    2295          11.6    82
# 395  28.0          4         120.0          79    2625          18.6    82
# 396  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %% [markdown]
# *a)*
# -  qualitative: name and origin.
# -  quantitative: mpg, cylinders, displacment, horsepower, weight, accelelration

# %%
# b)
quantitative = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration"]
for col in quantitative:
    print(f"Range of (Max/Min) {col}: {data[col].max()}/{data[col].min()}\n")
# Out:
# Range of (Max/Min) mpg: 46.6/9.0
#
# Range of (Max/Min) cylinders: 8/3
#
# Range of (Max/Min) displacement: 455.0/68.0
#
# Range of (Max/Min) horsepower: 230/46
#
# Range of (Max/Min) weight: 5140/1613
#
# Range of (Max/Min) acceleration: 24.8/8.0

# %%
# c)

for col in quantitative:
    print(f"For {col} the standard deviation is {data[col].std()} and mean is {data[col].mean()}\n")
# Out:
# For mpg the standard deviation is 7.8050074865717995 and mean is 23.445918367346938
#
# For cylinders the standard deviation is 1.7057832474527845 and mean is 5.471938775510204
#
# For displacement the standard deviation is 104.64400390890466 and mean is 194.41198979591837
#
# For horsepower the standard deviation is 38.49115993282849 and mean is 104.46938775510205
#
# For weight the standard deviation is 849.4025600429492 and mean is 2977.5841836734694
#
# For acceleration the standard deviation is 2.758864119188082 and mean is 15.541326530612244

# %%
# d)

reduced_data = data.drop(data.index[10:85])

reduced_data
for col in quantitative:
    print(f"For {col}:\n MAX/MIN {reduced_data[col].max()}/{reduced_data[col].min()}")
    print(f" STD: {reduced_data[col].std()}\n Mean: {reduced_data[col].mean()}\n\n")
# Out:
# For mpg:
#  MAX/MIN 46.6/11.0
#  STD: 7.872564543483587
#  Mean: 24.374763406940065
#
#
# For cylinders:
#  MAX/MIN 8/3
#  STD: 1.6581347994229967
#  Mean: 5.381703470031546
#
#
# For displacement:
#  MAX/MIN 455.0/68.0
#  STD: 100.16997334270233
#  Mean: 187.8801261829653
#
#
# For horsepower:
#  MAX/MIN 230/46
#  STD: 36.003208227537144
#  Mean: 101.0031545741325
#
#
# For weight:
#  MAX/MIN 4997/1649
#  STD: 811.640667914713
#  Mean: 2938.8548895899053
#
#
# For acceleration:
#  MAX/MIN 24.8/8.5
#  STD: 2.719912896949601
#  Mean: 15.704100946372236

# %%
quantitative
# Out:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration']

# %%
# e)

import matplotlib.pyplot as plt 

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

axes[0].scatter(data["weight"], data["mpg"])
axes[0].set_xlabel("Weight")
axes[0].set_ylabel("MPG")
axes[0].set_title("Plot 1: Weight vs MPG")

axes[1].scatter(data["horsepower"], data["mpg"])
axes[1].set_xlabel("Horsepower")
axes[1].set_ylabel("MPG")
axes[1].set_title("Plot 2: Horsepower vs MPG")

axes[2].scatter(data["horsepower"], data["acceleration"])
axes[2].set_xlabel("Horsepower")
axes[2].set_ylabel("Acceleration")
axes[2].set_title("Plot 3: Horsepower vs Acceleration")


plt.tight_layout()


plt.show()

# %% [markdown]
# *Weight vs MPG*
#
# Ser vi en tydlig minskning i MPG ju tyngre bilen blir. Vikten på fordonet spelar roll i hur mycket energi som behövs för att flytta fordonet framåt.
#
# *Horsepower vs MPG*
#
# Lika så med hästkrafter. Det krävs mer lgrad energi för att få ut mer hästkrafter ur en förbränningsmotor. Så ju mer kraft motorn har, ju mer sopp drar den.
#
# *Horsepower vs Acceleration*
#
# Med alla den kraften dock som du får ut av att bränna mer bränsle. Ju snabbare accelrera fordonet till 60 mph.

# %% [markdown]
# *f)*
#
# Vikt och hätskrafter på verkar hur mycket bilen drar. Ser det tydligt i diagramen att när vikten blir tyngre eller effkten av motron ökar så dra bilen mer. Är också fysik. Krävs mer energi att flytta en tyngre vikt eller producera mer kraft.
